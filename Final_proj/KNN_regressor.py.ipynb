# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import neighbors
from sklearn import tree 

def preprocessing():
    df = pd.read_csv('car.csv')
    
    #delete unnecessary data columns
    df = df.drop(df.index[0]) #drop the label, say the first row , NOT IN PLACE
    del df['body_type']
    del df['color_slug']
    del df['stk_year']
    del df['date_created']
    del df['date_last_seen']
    df = df.dropna() #drop row with na value, NOT IN PLACE
    
    print(df)
    car_name = df[['maker']]
    car_name.dtypes.value_counts()
    #new_df = df[df['maker']=='ford']
    #print(new_df)
    #new_df2 = df[df['maker']=='skoda']
    #print(new_df2)
    return df
def draw_PDF(df): #draw the pdf of each column
    df = df.values.tolist()
    print("tft",type(df))
    for i in range (len(df)): #Turn the None into 0
        for j in range (len(df[0])):
            if df[i][j] == None:
                df[i][j] = 0
                
            
    df = np.array(df)
    print("tft",type(df))
    for i in range(len(df[0])):
        tf = df[:,i]
        print("tf be like ",tf)
        tf.sort()
        weight_percent = np.ones_like(tf)/float(len(tf))
        plt.title(f' feature {i+1}: PDF')
        plt.tight_layout()
        plt.savefig(f' feature {i+1}: PDF',dpi=600)
    
if __name__ == '__main__':
    draw_PDF(preprocessing())
# Out:
# /home/alfons/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (7,8,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
#                  maker              model   mileage  manufacture_year  \
# 1                skoda            octavia  143476.0            2012.0
# 3                skoda              fabia  111970.0            2004.0
# 4                skoda              fabia  128886.0            2004.0
# 5                skoda              fabia  140932.0            2003.0
# 6                skoda              fabia  167220.0            2001.0
# 8                skoda            octavia  105389.0            2003.0
# 13               skoda            favorit   41250.0            1990.0
# 14              suzuki              swift  122100.0            2003.0
# 15              nissan            x-trail  149465.0            2005.0
# 17                opel              astra  316054.0            2005.0
# 18               skoda             superb  269398.0            2005.0
# 19               skoda              fabia   87257.0            2008.0
# 20               skoda              fabia  130340.0            2001.0
# 21                ford              focus  227415.0            2002.0
# 23                ford             fiesta   84476.0            1997.0
# 24             citroen         c4-picasso  112313.0            2007.0
# 25                seat              ibiza   86484.0            2007.0
# 27                audi                 a6  207427.0            2007.0
# 29              suzuki              swift  113175.0            2013.0
# 30                 kia               soul   40184.0            2010.0
# 32               skoda              fabia  186838.0            2007.0
# 33               skoda              fabia   97070.0            2007.0
# 36                ford              focus  159427.0            2012.0
# 37                ford             galaxy  160235.0            2012.0
# 38               skoda           roomster  125341.0            2007.0
# 39               skoda            octavia   38513.0            2009.0
# 40               skoda              fabia   87777.0            2005.0
# 41               skoda              fabia   98835.0            2005.0
# 42             citroen                 c5  143130.0            2011.0
# 44                ford              c-max   99713.0            2008.0
# ...                ...                ...       ...               ...
# 3550225           seat              ibiza  165669.0            2000.0
# 3550226          skoda            octavia  153000.0            2014.0
# 3550227          honda               cr-v   86000.0            2013.0
# 3550228        citroen         c4-picasso  124084.0            2014.0
# 3550229        citroen         c4-picasso  120335.0            2013.0
# 3550230  mercedes-benz           e200-cdi   16000.0            2016.0
# 3550233        citroen         c4-picasso  154803.0            2013.0
# 3550234       chrysler            voyager  159000.0            2004.0
# 3550245               1390.0          55.0          man          5          5
# 3550246               1783.0          88.0          man          5          5
# 3550247               1461.0          74.0          man          5          5
# 3550248               1461.0          79.0          man          5          5
# 3550250               1896.0          74.0          man          5          5
# 3550253               1397.0          50.0          man          5          5
# 3550254               2993.0         180.0         auto          5          5
# 3550255               1242.0          51.0          man          5          5
# 3550256               1896.0          77.0          man          5          5
# 3550257               1984.0          96.0          man          4          5
# 3550258               1360.0          54.0          man          5          5
# 3550261               1910.0          85.0          man          5          5
# 3550264               1968.0         103.0         auto          5          5
# 3550267               1360.0          54.0          man          5          5
#
#         fuel_type  price_eur
# 1          diesel    8882.31
# 3        gasoline    2960.77
# 4        gasoline    2738.71
# 5        gasoline    1628.42
# 6        gasoline    2072.54
# 8          diesel    4293.12
# 13       gasoline     370.10
# 14       gasoline     999.26
# 15       gasoline    4811.25
# 17         diesel    2331.61
# 18         diesel    4663.21
# 19       gasoline    4219.10
# 20       gasoline    2442.64
# 21         diesel    2146.56
# 23       gasoline     740.19
# 24       gasoline    7105.85
# 25       gasoline    3700.96
# 27         diesel    8882.31
# 29       gasoline    7401.92
# 30       gasoline    6883.79
# 32         diesel    4293.12
# 33       gasoline    3182.83
# 36         diesel    8771.28
# 37         diesel   11102.89
# 38         diesel    5218.36
# 39       gasoline    7957.07
# 40         diesel    3256.85
# 41         diesel    3923.02
# 42         diesel    7512.95
# 44       gasoline    6476.68
# ...           ...        ...
# 3550225  gasoline    1295.34
# 3550226    diesel    1295.34
# 3550227  gasoline    1295.34
# 3550228    diesel    1295.34
# 3550229    diesel    1295.34
# 3550230    diesel    1295.34
# 3550233  gasoline    1295.34
# 3550234    diesel    1295.34
# 3550235  gasoline    1295.34
# 3550237    diesel    1295.34
# 3550238  gasoline    1295.34
# 3550240  gasoline    1295.34
# 3550241    diesel    1295.34
# 3550242  gasoline    1295.34
# 3550243    diesel    1295.34
# 3550244  gasoline    1295.34
# 3550245  gasoline    1295.34
# 3550246  gasoline    1295.34
# 3550247    diesel    1295.34
# 3550248    diesel    1295.34
# 3550250    diesel    1295.34
# 3550253  gasoline    1295.34
# 3550254    diesel    1295.34
# 3550255  gasoline    1295.34
# 3550256    diesel    1295.34
# 3550257  gasoline    1295.34
# 3550258  gasoline    1295.34
# 3550261    diesel    1295.34
# 3550264    diesel    1295.34
# 3550267  gasoline    1295.34
#
# [523285 rows x 11 columns]
# tft <class 'list'>
# tft <class 'numpy.ndarray'>
# tf be like  ['skoda' 'skoda' 'skoda' ..., 'fiat' 'volkswagen' 'citroen']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-26cdeef3fdfc> in <module>()
#      46
#      47 if __name__ == '__main__':
# ---> 48     draw_PDF(preprocessing())
#      49
#      50
#
# <ipython-input-8-26cdeef3fdfc> in draw_PDF(df)
#      40         print("tf be like ",tf)
#      41         tf.sort()
# ---> 42         weight_percent = np.ones_like(tf)/float(len(tf))
#      43         plt.title(f' feature {i+1}: PDF')
#      44         plt.tight_layout()
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
